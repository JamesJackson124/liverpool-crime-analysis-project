# %%
# Import core libraries for file handling and data analysis
import os
import pandas as pd

# %%
# Set the path to the folder containing all 12 CSV crime data files
folder_path = r"/Users/jamesjackson/Library/Mobile Documents/com~apple~CloudDocs/Documents/Upskilling/liverpool_crime_analysis/csv_files"

# %%
# List all files in the folder
files = os.listdir(folder_path)

# Filter out only CSV files (just in case)
csv_files = [file for file in files if file.endswith('.csv')]

# Sort the files to keep them in chronological order
csv_files.sort()

# Initialize an empty list to hold individual DataFrames
df_list = []

for file in csv_files:
    file_path = os.path.join(folder_path, file)  # Full path to file
    df = pd.read_csv(file_path)  # Read the CSV
    df_list.append(df)  # Add to list

# Concatenate all DataFrames vertically into one
crime_data = pd.concat(df_list, ignore_index=True)

# Check the combined DataFrame's shape (rows, columns)
print(f"Combined DataFrame shape: {crime_data.shape}")

# Preview first 5 rows
crime_data.head()
# Out:
# Combined DataFrame shape: (150535, 12)
#                                             Crime ID    Month  \
# 0  7c903b55af24fe6dab7eb96fe696f8e7d57e05817f6730...  2024-06
# 1  461fe1ff825ef4cc740dafe58e9015449696d80978580a...  2024-06
# 2                                                NaN  2024-06
# 3  ebeec31356de0e9219711d81f3d8006d33c275e04e9e7a...  2024-06
# 4  b04da555d9c4f211ce48bf6453dc0f6257c63785727ec6...  2024-06
#
#          Reported by       Falls within  Longitude   Latitude  \
# 0  Merseyside Police  Merseyside Police  -2.746819  53.389101
# 1  Merseyside Police  Merseyside Police  -2.798814  53.354705
# 2  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 3  Merseyside Police  Merseyside Police  -2.871229  53.489300
# 4  Merseyside Police  Merseyside Police  -2.871827  53.489763
#
#                                          Location  LSOA code      LSOA name  \
# 0  On or near Further/Higher Educational Building  E01012393    Halton 001B
# ...

# %%
# Preview final 5 rows
combined_df.tail()
# Out:
#                                                  Crime ID    Month  \
# 150530  d2db866eae5d3bdd90964efd28213ec5b9c492eed239c7...  2025-05
# 150531  47752c2d18bcc9513435609a10d275576368ee776e48ee...  2025-05
# 150532  1a7ddb07d9811ce32087c089bdf971b835155361d56e85...  2025-05
# 150533  bd33393bee7aec843d2110c76a7d947b23351c2cee5b7c...  2025-05
# 150534  9b444cd7d8250185307021cc44393ea5ef627748a1dec2...  2025-05
#
#               Reported by       Falls within  Longitude   Latitude  \
# 150530  Merseyside Police  Merseyside Police  -2.962543  53.313100
# 150531  Merseyside Police  Merseyside Police  -2.965022  53.311884
# 150532  Merseyside Police  Merseyside Police  -2.966483  53.310785
# 150533  Merseyside Police  Merseyside Police  -2.967579  53.310137
# 150534  Merseyside Police  Merseyside Police  -2.969782  53.309311
#
#                            Location  LSOA code    LSOA name  \
# 150530      On or near Stanley Lane  E01007169  Wirral 042E
# ...

# %%
# Save the combined DataFrame as 'liverpool_crime_data.csv' in the same folder as the original CSV files
crime_data.to_csv(folder_path + '/liverpool_crime_data.csv', index=False)
