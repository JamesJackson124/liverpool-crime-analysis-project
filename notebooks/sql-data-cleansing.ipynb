# %%
# Import pandas for data manipulation and SQLAlchemy for database interaction

import pandas as pd
from sqlalchemy import create_engine

# %%
# Define the path to the CSV file and the SQLite database file

csv_path = '/Users/jamesjackson/Documents/liverpool_crime_analysis/csv_files/liverpool_crime_data.csv'

db_path = '/Users/jamesjackson/Documents/liverpool_crime_analysis/liverpool_crime.db'

# %%
# Read the CSV into a pandas DataFrame

df = pd.read_csv(csv_path)

# Check the first few rows to confirm it loaded correctly
df.head()
# Out:
#                                             Crime ID    Month  \
# 0  7c903b55af24fe6dab7eb96fe696f8e7d57e05817f6730...  2024-06
# 1  461fe1ff825ef4cc740dafe58e9015449696d80978580a...  2024-06
# 2                                                NaN  2024-06
# 3  ebeec31356de0e9219711d81f3d8006d33c275e04e9e7a...  2024-06
# 4  b04da555d9c4f211ce48bf6453dc0f6257c63785727ec6...  2024-06
#
#          Reported by       Falls within  Longitude   Latitude  \
# 0  Merseyside Police  Merseyside Police  -2.746819  53.389101
# 1  Merseyside Police  Merseyside Police  -2.798814  53.354705
# 2  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 3  Merseyside Police  Merseyside Police  -2.871229  53.489300
# 4  Merseyside Police  Merseyside Police  -2.871827  53.489763
#
#                                          Location  LSOA code      LSOA name  \
# 0  On or near Further/Higher Educational Building  E01012393    Halton 001B
# 1                      On or near Old Higher Road  E01012391    Halton 008B
# 2                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 3                          On or near Watts Close  E01006448  Knowsley 001A
# 4                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
#
#                   Crime type                          Last outcome category  \
# 0                      Drugs                               Local resolution
# 1  Criminal damage and arson  Investigation complete; no suspect identified
# 2      Anti-social behaviour                                            NaN
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson                    Unable to prosecute suspect
#
#    Context
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# Create a connection engine to the SQLite database file

engine = create_engine(f'sqlite:///{db_path}')

# %%
# Write the DataFrame to a table named 'crime_data' in the database
# If the table exists, replace it

df.to_sql('crime_data', engine, if_exists='replace', index=False)
# Out:
# 150535

# %%
from sqlalchemy import text

# Check what tables exist in the database now

with engine.connect() as conn:

    result = conn.execute(text("SELECT name FROM sqlite_master WHERE type='table';"))

    tables = [row[0] for row in result]

print("Tables in database:", tables)
# Out:
# Tables in database: ['crime_data']

# %%
from sqlalchemy import text

# Run a SQL query to count total rows in 'crime_data'

with engine.connect() as conn:

    result = conn.execute(text("SELECT COUNT(*) AS total_rows FROM crime_data;"))

    total_rows = result.fetchone()[0]

print("Total rows in crime_data:", total_rows)
# Out:
# Total rows in crime_data: 150535

# %%
from sqlalchemy import text

# Step 8: Count distinct crime types in the data

with engine.connect() as conn:
    result = conn.execute(text('SELECT COUNT(DISTINCT "Crime type") AS unique_crime_types FROM crime_data;'))
    unique_crimes = result.fetchone()[0]

print("Unique crime types:", unique_crimes)
# Out:
# Unique crime types: 14

# %%
# Example: Get all records for a specific crime type, e.g. 'Burglary'

query = """
SELECT *
FROM crime_data
WHERE "Crime type" = 'Burglary'
LIMIT 5;
"""

with engine.connect() as conn:
    burglary_samples = pd.read_sql_query(query, conn)

burglary_samples
# Out:
#                                             Crime ID    Month  \
# 0  299a8fa1ce72c3e87de73560bee9faf6606862f1a06079...  2024-06
# 1  3f68851792c5677094ba81c48a49e848b98fd93f76af3d...  2024-06
# 2  d33996c2cf26ee35ce4eabcc681cde10ba4c8cde77bfbe...  2024-06
# 3  68bd39d6a9d022fb342e3d319439d4752f3af80b5db69b...  2024-06
# 4  4a7bc9cb21d15e0b628d789282b159bc02e8d62e708c28...  2024-06
#
#          Reported by       Falls within  Longitude   Latitude  \
# 0  Merseyside Police  Merseyside Police  -2.867785  53.490368
# 1  Merseyside Police  Merseyside Police  -2.878243  53.496134
# 2  Merseyside Police  Merseyside Police  -2.876911  53.465888
# 3  Merseyside Police  Merseyside Police  -2.860352  53.479851
# 4  Merseyside Police  Merseyside Police  -2.863481  53.438022
#
#                           Location  LSOA code      LSOA name Crime type  \
# 0      On or near Warrenhouse Road  E01006494  Knowsley 001D   Burglary
# 1           On or near Stocks Road  E01006494  Knowsley 001D   Burglary
# 2         On or near Old Farm Road  E01006418  Knowsley 005B   Burglary
# 3           On or near Webber Road  E01006446  Knowsley 005G   Burglary
# 4  On or near Blackthorne Crescent  E01006413  Knowsley 006B   Burglary
#
#                            Last outcome category Context
# 0  Investigation complete; no suspect identified    None
# 1                       Court result unavailable    None
# 2  Investigation complete; no suspect identified    None
# 3  Investigation complete; no suspect identified    None
# 4  Investigation complete; no suspect identified    None

# %%
from sqlalchemy import text

# Count how many rows have a missing Crime ID (NULL values)
with engine.connect() as conn:
    result = conn.execute(text('SELECT COUNT(*) FROM crime_data WHERE "Crime ID" IS NULL;'))
    missing_crime_id_count = result.scalar()

print(f"Number of rows with missing Crime ID: {missing_crime_id_count}")
# Out:
# Number of rows with missing Crime ID: 16252

# %%
# Check for duplicated Crime IDs by counting how many have more than one occurrence

from sqlalchemy import text

with engine.connect() as conn:
    query = text("""
        SELECT "Crime ID", COUNT(*) AS count
        FROM crime_data
        WHERE "Crime ID" IS NOT NULL
        GROUP BY "Crime ID"
        HAVING COUNT(*) > 1;
    """)
    result = conn.execute(query)
    duplicates = result.fetchall()

print(f"Number of duplicated Crime IDs: {len(duplicates)}")
# Out:
# Number of duplicated Crime IDs: 0

# %%
import pandas as pd
from sqlalchemy import text

# Fetch rows with NULL Crime ID and show as DataFrame
with engine.connect() as conn:
    result = conn.execute(text('SELECT * FROM crime_data WHERE "Crime ID" IS NULL LIMIT 15;'))
    null_entries = result.fetchall()
    columns = result.keys()

null_df = pd.DataFrame(null_entries, columns=columns)
null_df.head(15)
# Out:
#    Crime ID    Month        Reported by       Falls within  Longitude  \
# 0      None  2024-06  Merseyside Police  Merseyside Police  -2.871827
# 1      None  2024-06  Merseyside Police  Merseyside Police  -2.870433
# 2      None  2024-06  Merseyside Police  Merseyside Police  -2.878943
# 3      None  2024-06  Merseyside Police  Merseyside Police  -2.878943
# 4      None  2024-06  Merseyside Police  Merseyside Police  -2.879075
# 5      None  2024-06  Merseyside Police  Merseyside Police  -2.882803
# 6      None  2024-06  Merseyside Police  Merseyside Police  -2.899482
# 7      None  2024-06  Merseyside Police  Merseyside Police  -2.904851
# 8      None  2024-06  Merseyside Police  Merseyside Police  -2.887114
# 9      None  2024-06  Merseyside Police  Merseyside Police  -2.887114
# 10     None  2024-06  Merseyside Police  Merseyside Police  -2.895755
# 11     None  2024-06  Merseyside Police  Merseyside Police  -2.890870
# 12     None  2024-06  Merseyside Police  Merseyside Police  -2.896144
# 13     None  2024-06  Merseyside Police  Merseyside Police  -2.876073
# 14     None  2024-06  Merseyside Police  Merseyside Police  -2.876073
#
#      Latitude                      Location  LSOA code      LSOA name  \
# 0   53.489763  On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 1   53.490888     On or near Woodcote Close  E01006494  Knowsley 001D
# 2   53.489891    On or near Roughwood Drive  E01006494  Knowsley 001D
# 3   53.489891    On or near Roughwood Drive  E01006494  Knowsley 001D
# 4   53.491876      On or near Highbarn Road  E01006495  Knowsley 001E
# 5   53.489970    On or near Brookwood Court  E01006495  Knowsley 001E
# 6   53.489684     On or near Chiltern Drive  E01006454  Knowsley 002A
# 7   53.491243       On or near Beldale Park  E01006454  Knowsley 002A
# 8   53.484221         On or near Hall Drive  E01006457  Knowsley 002C
# 9   53.484221         On or near Hall Drive  E01006457  Knowsley 002C
# 10  53.489469       On or near Parking Area  E01006458  Knowsley 002D
# 11  53.501632      On or near Lexington Way  E01006491  Knowsley 002F
# 12  53.475066  On or near Little Brook Lane  E01006415  Knowsley 003A
# 13  53.469813    On or near Peatwood Avenue  E01006417  Knowsley 003B
# 14  53.469813    On or near Peatwood Avenue  E01006417  Knowsley 003B
#
#                Crime type Last outcome category Context
# 0   Anti-social behaviour                  None    None
# 1   Anti-social behaviour                  None    None
# 2   Anti-social behaviour                  None    None
# 3   Anti-social behaviour                  None    None
# 4   Anti-social behaviour                  None    None
# 5   Anti-social behaviour                  None    None
# 6   Anti-social behaviour                  None    None
# 7   Anti-social behaviour                  None    None
# 8   Anti-social behaviour                  None    None
# 9   Anti-social behaviour                  None    None
# 10  Anti-social behaviour                  None    None
# 11  Anti-social behaviour                  None    None
# 12  Anti-social behaviour                  None    None
# 13  Anti-social behaviour                  None    None
# 14  Anti-social behaviour                  None    None

# %%
from sqlalchemy import text

# Count how many rows with NULL Crime ID have Crime type 'Anti-social behaviour'
with engine.connect() as conn:
    result = conn.execute(text('''
        SELECT COUNT(*) 
        FROM crime_data 
        WHERE "Crime ID" IS NULL AND "Crime type" = 'Anti-social behaviour';
    '''))
    count = result.scalar()

print(f"Number of NULL Crime ID rows with 'Anti-social behaviour': {count}")
# Out:
# Number of NULL Crime ID rows with 'Anti-social behaviour': 16252

# %%
from sqlalchemy import text

# Count how many rows with non-NULL Crime ID have Crime type 'Anti-social behaviour'
with engine.connect() as conn:
    result = conn.execute(text('''
        SELECT COUNT(*) 
        FROM crime_data 
        WHERE "Crime ID" IS NOT NULL AND "Crime type" = 'Anti-social behaviour';
    '''))
    count_non_null = result.scalar()

print(f"Number of non-NULL Crime ID rows with 'Anti-social behaviour': {count_non_null}")

#Learnt that anti-social behaviour crimes do not have an associated Crime ID
# Out:
# Number of non-NULL Crime ID rows with 'Anti-social behaviour': 0

# %%
from sqlalchemy import text

# Update Crime ID to 'ASB_FILL' where Crime ID is NULL and Crime type is 'Anti-social behaviour'
with engine.connect() as conn:
    conn.execute(
        text("""
            UPDATE crime_data
            SET "Crime ID" = 'ASB_FILL'
            WHERE "Crime ID" IS NULL
            AND "Crime type" = 'Anti-social behaviour';
        """)
    )
    conn.commit()  # Commit the transaction

# %%
from sqlalchemy import text
import pandas as pd

# Use engine.begin() for automatic commit
with engine.begin() as conn:
    conn.execute(
        text("""
            UPDATE crime_data
            SET "Crime ID" = 'ASB_FILL'
            WHERE "Crime ID" IS NULL
            AND "Crime type" = 'Anti-social behaviour';
        """)
    )

    # Now fetch updated rows to confirm
    result = conn.execute(
        text("SELECT * FROM crime_data WHERE \"Crime ID\" = 'ASB_FILL' LIMIT 5;")
    )
    updated_rows = result.fetchall()
    columns = result.keys()

updated_df = pd.DataFrame(updated_rows, columns=columns)
updated_df.head()
# Out:
#    Crime ID    Month        Reported by       Falls within  Longitude  \
# 0  ASB_FILL  2024-06  Merseyside Police  Merseyside Police  -2.871827
# 1  ASB_FILL  2024-06  Merseyside Police  Merseyside Police  -2.870433
# 2  ASB_FILL  2024-06  Merseyside Police  Merseyside Police  -2.878943
# 3  ASB_FILL  2024-06  Merseyside Police  Merseyside Police  -2.878943
# 4  ASB_FILL  2024-06  Merseyside Police  Merseyside Police  -2.879075
#
#     Latitude                      Location  LSOA code      LSOA name  \
# 0  53.489763  On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 1  53.490888     On or near Woodcote Close  E01006494  Knowsley 001D
# 2  53.489891    On or near Roughwood Drive  E01006494  Knowsley 001D
# 3  53.489891    On or near Roughwood Drive  E01006494  Knowsley 001D
# 4  53.491876      On or near Highbarn Road  E01006495  Knowsley 001E
#
#               Crime type Last outcome category Context
# 0  Anti-social behaviour                  None    None
# 1  Anti-social behaviour                  None    None
# 2  Anti-social behaviour                  None    None
# 3  Anti-social behaviour                  None    None
# 4  Anti-social behaviour                  None    None

# %%
# Reload fresh data from the database after update
with engine.connect() as conn:
    result = conn.execute(text('SELECT * FROM crime_data LIMIT 5;'))
    rows = result.fetchall()
    columns = result.keys()

fresh_df = pd.DataFrame(rows, columns=columns)
fresh_df.head()
# Out:
#                                             Crime ID    Month  \
# 0  7c903b55af24fe6dab7eb96fe696f8e7d57e05817f6730...  2024-06
# 1  461fe1ff825ef4cc740dafe58e9015449696d80978580a...  2024-06
# 2                                           ASB_FILL  2024-06
# 3  ebeec31356de0e9219711d81f3d8006d33c275e04e9e7a...  2024-06
# 4  b04da555d9c4f211ce48bf6453dc0f6257c63785727ec6...  2024-06
#
#          Reported by       Falls within  Longitude   Latitude  \
# 0  Merseyside Police  Merseyside Police  -2.746819  53.389101
# 1  Merseyside Police  Merseyside Police  -2.798814  53.354705
# 2  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 3  Merseyside Police  Merseyside Police  -2.871229  53.489300
# 4  Merseyside Police  Merseyside Police  -2.871827  53.489763
#
#                                          Location  LSOA code      LSOA name  \
# 0  On or near Further/Higher Educational Building  E01012393    Halton 001B
# 1                      On or near Old Higher Road  E01012391    Halton 008B
# 2                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 3                          On or near Watts Close  E01006448  Knowsley 001A
# 4                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
#
#                   Crime type                          Last outcome category  \
# 0                      Drugs                               Local resolution
# 1  Criminal damage and arson  Investigation complete; no suspect identified
# 2      Anti-social behaviour                                           None
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson                    Unable to prosecute suspect
#
#   Context
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
from sqlalchemy import text

# List columns to check for missing values (NULL or empty string)
columns_to_check = [
    "Crime ID", "Month", "Reported by", "Falls within", "Longitude",
    "Latitude", "Location", "LSOA code", "LSOA name", "Crime type",
    "Last outcome category", "Context"
]

with engine.connect() as conn:
    for col in columns_to_check:
        # SQL query to count rows where column is NULL or empty string
        query = text(f'SELECT COUNT(*) AS missing_count FROM crime_data WHERE "{col}" IS NULL OR "{col}" = \'\';')
        result = conn.execute(query)
        missing_count = result.scalar()
        print(f"Missing in {col}: {missing_count}")  # Display missing counts per column
# Out:
# Missing in Crime ID: 0
# Missing in Month: 0
# Missing in Reported by: 0
# Missing in Falls within: 0
# Missing in Longitude: 0
# Missing in Latitude: 0
# Missing in Location: 0
# Missing in LSOA code: 0
# Missing in LSOA name: 0
# Missing in Crime type: 0
# Missing in Last outcome category: 16252
# Missing in Context: 150535

# %%
# Drop the 'Context' column because it is completely missing (all values are NULL)
with engine.connect() as conn:
    conn.execute(text('ALTER TABLE crime_data RENAME TO crime_data_old;'))
    conn.execute(text('''
        CREATE TABLE crime_data AS
        SELECT 
            "Crime ID", "Month", "Reported by", "Falls within",
            "Longitude", "Latitude", "Location", "LSOA code",
            "LSOA name", "Crime type", "Last outcome category"
        FROM crime_data_old;
    '''))
    conn.execute(text('DROP TABLE crime_data_old;'))
    conn.commit()

# Confirm the column is dropped by checking columns
with engine.connect() as conn:
    result = conn.execute(text("PRAGMA table_info(crime_data);"))
    columns = [row[1] for row in result.fetchall()]

import pandas as pd
pd.DataFrame(columns, columns=['Columns'])
# Out:
#                   Columns
# 0                Crime ID
# 1                   Month
# 2             Reported by
# 3            Falls within
# 4               Longitude
# 5                Latitude
# 6                Location
# 7               LSOA code
# 8               LSOA name
# 9              Crime type
# 10  Last outcome category

# %%
# Fetch the first 10 rows from the updated crime_data table to check the current state of the data
with engine.connect() as conn:
    result = conn.execute(text('SELECT * FROM crime_data LIMIT 10;'))
    rows = result.fetchall()
    columns = result.keys()

import pandas as pd
head_df = pd.DataFrame(rows, columns=columns)
head_df
# Out:
#                                             Crime ID    Month  \
# 0  7c903b55af24fe6dab7eb96fe696f8e7d57e05817f6730...  2024-06
# 1  461fe1ff825ef4cc740dafe58e9015449696d80978580a...  2024-06
# 2                                           ASB_FILL  2024-06
# 3  ebeec31356de0e9219711d81f3d8006d33c275e04e9e7a...  2024-06
# 4  b04da555d9c4f211ce48bf6453dc0f6257c63785727ec6...  2024-06
# 5  0e5d5be47f6fbb299f9ed00b4aa64cf7984475a98ddfe0...  2024-06
# 6  e822728454620d8fd43110852d8a16d4482849f60977f0...  2024-06
# 7  88d80f378f168ca985324ef2ebb4463286745500d47038...  2024-06
# 8  7bfc4eb5156b7f044982f2ab6f8d82eea5060636c55471...  2024-06
# 9  b6fba1fbba7cd0613983f452b27ad3fb62068f2a22b7e7...  2024-06
#
#          Reported by       Falls within  Longitude   Latitude  \
# 0  Merseyside Police  Merseyside Police  -2.746819  53.389101
# 1  Merseyside Police  Merseyside Police  -2.798814  53.354705
# 2  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 3  Merseyside Police  Merseyside Police  -2.871229  53.489300
# 4  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 5  Merseyside Police  Merseyside Police  -2.871229  53.489300
# 6  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 7  Merseyside Police  Merseyside Police  -2.870117  53.489452
# 8  Merseyside Police  Merseyside Police  -2.870190  53.485658
# 9  Merseyside Police  Merseyside Police  -2.871229  53.489300
#
#                                          Location  LSOA code      LSOA name  \
# 0  On or near Further/Higher Educational Building  E01012393    Halton 001B
# 1                      On or near Old Higher Road  E01012391    Halton 008B
# 2                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 3                          On or near Watts Close  E01006448  Knowsley 001A
# 4                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 5                          On or near Watts Close  E01006448  Knowsley 001A
# 6                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 7                         On or near Jarrett Road  E01006448  Knowsley 001A
# 8                         On or near Darmond Road  E01006448  Knowsley 001A
# 9                          On or near Watts Close  E01006448  Knowsley 001A
#
#                      Crime type                          Last outcome category
# 0                         Drugs                               Local resolution
# 1     Criminal damage and arson  Investigation complete; no suspect identified
# 2         Anti-social behaviour                                           None
# 3     Criminal damage and arson  Investigation complete; no suspect identified
# 4     Criminal damage and arson                    Unable to prosecute suspect
# 5                         Drugs                    Unable to prosecute suspect
# 6                         Drugs                       Court result unavailable
# 7                  Public order  Investigation complete; no suspect identified
# 8                 Vehicle crime  Investigation complete; no suspect identified
# 9  Violence and sexual offences                    Unable to prosecute suspect

# %%
from sqlalchemy import text
import pandas as pd

# As all null values are from ASB crime types, we fill NULL values in 'Last outcome category' with 'ASB_FILL' for 'Anti-social behaviour' crimes

with engine.connect() as conn:
    conn.execute(
        text("""
            UPDATE crime_data
            SET "Last outcome category" = 'ASB_FILL'
            WHERE "Last outcome category" IS NULL
            AND "Crime type" = 'Anti-social behaviour';
        """)
    )
    conn.commit()

    # Fetch first 5 rows of the updated table to confirm
    result = conn.execute(
        text("SELECT * FROM crime_data LIMIT 5;")
    )
    updated_rows = result.fetchall()
    columns = result.keys()

updated_df = pd.DataFrame(updated_rows, columns=columns)
updated_df.head()
# Out:
#                                             Crime ID    Month  \
# 0  7c903b55af24fe6dab7eb96fe696f8e7d57e05817f6730...  2024-06
# 1  461fe1ff825ef4cc740dafe58e9015449696d80978580a...  2024-06
# 2                                           ASB_FILL  2024-06
# 3  ebeec31356de0e9219711d81f3d8006d33c275e04e9e7a...  2024-06
# 4  b04da555d9c4f211ce48bf6453dc0f6257c63785727ec6...  2024-06
#
#          Reported by       Falls within  Longitude   Latitude  \
# 0  Merseyside Police  Merseyside Police  -2.746819  53.389101
# 1  Merseyside Police  Merseyside Police  -2.798814  53.354705
# 2  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 3  Merseyside Police  Merseyside Police  -2.871229  53.489300
# 4  Merseyside Police  Merseyside Police  -2.871827  53.489763
#
#                                          Location  LSOA code      LSOA name  \
# 0  On or near Further/Higher Educational Building  E01012393    Halton 001B
# 1                      On or near Old Higher Road  E01012391    Halton 008B
# 2                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 3                          On or near Watts Close  E01006448  Knowsley 001A
# 4                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
#
#                   Crime type                          Last outcome category
# 0                      Drugs                               Local resolution
# 1  Criminal damage and arson  Investigation complete; no suspect identified
# 2      Anti-social behaviour                                       ASB_FILL
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson                    Unable to prosecute suspect

# %%
# Rename columns to be lowercase and replace spaces with underscores for consistency

with engine.connect() as conn:
    conn.execute(text("""
        ALTER TABLE crime_data RENAME TO crime_data_old;
    """))
    # Create new table with renamed columns
    conn.execute(text("""
        CREATE TABLE crime_data (
            crime_id TEXT,
            month TEXT,
            reported_by TEXT,
            falls_within TEXT,
            longitude REAL,
            latitude REAL,
            location TEXT,
            lsoa_code TEXT,
            lsoa_name TEXT,
            crime_type TEXT,
            last_outcome_category TEXT
        );
    """))
    # Copy data from old table to new table, mapping old columns to new names
    conn.execute(text("""
        INSERT INTO crime_data (
            crime_id, month, reported_by, falls_within,
            longitude, latitude, location, lsoa_code,
            lsoa_name, crime_type, last_outcome_category
        )
        SELECT
            "Crime ID", "Month", "Reported by", "Falls within",
            Longitude, Latitude, Location, "LSOA code",
            "LSOA name", "Crime type", "Last outcome category"
        FROM crime_data_old;
    """))
    # Drop old table
    conn.execute(text("DROP TABLE crime_data_old;"))
    conn.commit()

# Fetch first 5 rows to confirm changes and display as DataFrame
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM crime_data LIMIT 5;"))
    rows = result.fetchall()
    columns = result.keys()

renamed_df = pd.DataFrame(rows, columns=columns)
renamed_df.head()
# Out:
#                                             crime_id    month  \
# 0  7c903b55af24fe6dab7eb96fe696f8e7d57e05817f6730...  2024-06
# 1  461fe1ff825ef4cc740dafe58e9015449696d80978580a...  2024-06
# 2                                           ASB_FILL  2024-06
# 3  ebeec31356de0e9219711d81f3d8006d33c275e04e9e7a...  2024-06
# 4  b04da555d9c4f211ce48bf6453dc0f6257c63785727ec6...  2024-06
#
#          reported_by       falls_within  longitude   latitude  \
# 0  Merseyside Police  Merseyside Police  -2.746819  53.389101
# 1  Merseyside Police  Merseyside Police  -2.798814  53.354705
# 2  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 3  Merseyside Police  Merseyside Police  -2.871229  53.489300
# 4  Merseyside Police  Merseyside Police  -2.871827  53.489763
#
#                                          location  lsoa_code      lsoa_name  \
# 0  On or near Further/Higher Educational Building  E01012393    Halton 001B
# 1                      On or near Old Higher Road  E01012391    Halton 008B
# 2                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 3                          On or near Watts Close  E01006448  Knowsley 001A
# 4                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
#
#                   crime_type                          last_outcome_category
# 0                      Drugs                               Local resolution
# 1  Criminal damage and arson  Investigation complete; no suspect identified
# 2      Anti-social behaviour                                       ASB_FILL
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson                    Unable to prosecute suspect

# %%
# Check the data type of the 'month' column in the DataFrame
print(df['Month'].dtype)
# Out:
# object

# %%
import pandas as pd
from sqlalchemy import text

# Fetch a sample of rows from the database
with engine.connect() as conn:
    result = conn.execute(text('SELECT * FROM crime_data LIMIT 10;'))
    rows = result.fetchall()
    columns = result.keys()

# Create DataFrame from fetched data
df_sample = pd.DataFrame(rows, columns=columns)

# Convert 'month' column from string to datetime (year-month only)
df_sample['month'] = pd.to_datetime(df_sample['month'], format='%Y-%m')

# Show the updated dataframe with datetime 'month' column
df_sample.head(10)
# Out:
#                                             crime_id      month  \
# 0  7c903b55af24fe6dab7eb96fe696f8e7d57e05817f6730... 2024-06-01
# 1  461fe1ff825ef4cc740dafe58e9015449696d80978580a... 2024-06-01
# 2                                           ASB_FILL 2024-06-01
# 3  ebeec31356de0e9219711d81f3d8006d33c275e04e9e7a... 2024-06-01
# 4  b04da555d9c4f211ce48bf6453dc0f6257c63785727ec6... 2024-06-01
# 5  0e5d5be47f6fbb299f9ed00b4aa64cf7984475a98ddfe0... 2024-06-01
# 6  e822728454620d8fd43110852d8a16d4482849f60977f0... 2024-06-01
# 7  88d80f378f168ca985324ef2ebb4463286745500d47038... 2024-06-01
# 8  7bfc4eb5156b7f044982f2ab6f8d82eea5060636c55471... 2024-06-01
# 9  b6fba1fbba7cd0613983f452b27ad3fb62068f2a22b7e7... 2024-06-01
#
#          reported_by       falls_within  longitude   latitude  \
# 0  Merseyside Police  Merseyside Police  -2.746819  53.389101
# 1  Merseyside Police  Merseyside Police  -2.798814  53.354705
# 2  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 3  Merseyside Police  Merseyside Police  -2.871229  53.489300
# 4  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 5  Merseyside Police  Merseyside Police  -2.871229  53.489300
# 6  Merseyside Police  Merseyside Police  -2.871827  53.489763
# 7  Merseyside Police  Merseyside Police  -2.870117  53.489452
# 8  Merseyside Police  Merseyside Police  -2.870190  53.485658
# 9  Merseyside Police  Merseyside Police  -2.871229  53.489300
#
#                                          location  lsoa_code      lsoa_name  \
# 0  On or near Further/Higher Educational Building  E01012393    Halton 001B
# 1                      On or near Old Higher Road  E01012391    Halton 008B
# 2                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 3                          On or near Watts Close  E01006448  Knowsley 001A
# 4                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 5                          On or near Watts Close  E01006448  Knowsley 001A
# 6                    On or near Gilescroft Avenue  E01006448  Knowsley 001A
# 7                         On or near Jarrett Road  E01006448  Knowsley 001A
# 8                         On or near Darmond Road  E01006448  Knowsley 001A
# 9                          On or near Watts Close  E01006448  Knowsley 001A
#
#                      crime_type                          last_outcome_category
# 0                         Drugs                               Local resolution
# 1     Criminal damage and arson  Investigation complete; no suspect identified
# 2         Anti-social behaviour                                       ASB_FILL
# 3     Criminal damage and arson  Investigation complete; no suspect identified
# 4     Criminal damage and arson                    Unable to prosecute suspect
# 5                         Drugs                    Unable to prosecute suspect
# 6                         Drugs                       Court result unavailable
# 7                  Public order  Investigation complete; no suspect identified
# 8                 Vehicle crime  Investigation complete; no suspect identified
# 9  Violence and sexual offences                    Unable to prosecute suspect

# %%
with engine.connect() as conn:
    result = conn.execute(text('SELECT month FROM crime_data LIMIT 5;'))
    rows = result.fetchall()
    columns = result.keys()

df_check = pd.DataFrame(rows, columns=columns)
print(df_check.dtypes)
df_check.head()
# Out:
# month    object
# dtype: object
#      month
# 0  2024-06
# 1  2024-06
# 2  2024-06
# 3  2024-06
# 4  2024-06

# %%
from sqlalchemy import text
import pandas as pd

# Cleaning step: Identify and remove leading/trailing whitespace
# from text-based columns to ensure consistent data formatting
# This helps avoid issues with string comparisons and grouping later.

# Columns to check and trim whitespace from
text_columns = ['reported_by', 'falls_within', 'location', 'lsoa_code', 'lsoa_name', 'crime_type', 'last_outcome_category']

with engine.connect() as conn:
    # Step 1: Check how many rows in each column have leading/trailing whitespace
    for col in text_columns:
        query = text(f'''
            SELECT COUNT(*) AS count_with_whitespace
            FROM crime_data
            WHERE {col} <> TRIM({col});
        ''')
        result = conn.execute(query)
        count = result.scalar()
        print(f"Rows with leading/trailing whitespace in '{col}': {count}")
# Out:
# Rows with leading/trailing whitespace in 'reported_by': 0
# Rows with leading/trailing whitespace in 'falls_within': 0
# Rows with leading/trailing whitespace in 'location': 0
# Rows with leading/trailing whitespace in 'lsoa_code': 0
# Rows with leading/trailing whitespace in 'lsoa_name': 0
# Rows with leading/trailing whitespace in 'crime_type': 0
# Rows with leading/trailing whitespace in 'last_outcome_category': 0

# %%
from sqlalchemy import text
import pandas as pd

# Checking distinct values in key categorical columns to identify inconsistencies or cleanup needs

with engine.connect() as conn:
    # Distinct Crime Types
    result = conn.execute(text('SELECT DISTINCT crime_type FROM crime_data;'))
    crime_types = sorted(row[0] for row in result.fetchall())
    print("Crime Types:\n- " + "\n- ".join(crime_types) + "\n")

    # Distinct Reported By
    result = conn.execute(text('SELECT DISTINCT reported_by FROM crime_data;'))
    reported_by = sorted(row[0] for row in result.fetchall())
    print("Reported By:\n- " + "\n- ".join(reported_by) + "\n")

    # Distinct Last Outcome Categories
    result = conn.execute(text('SELECT DISTINCT last_outcome_category FROM crime_data;'))
    last_outcomes = sorted(str(row[0]) for row in result.fetchall())  # convert None to 'None' string if any
    print("Last Outcome Categories:\n- " + "\n- ".join(last_outcomes) + "\n")
# Out:
# Crime Types:
# - Anti-social behaviour
# - Bicycle theft
# - Burglary
# - Criminal damage and arson
# - Drugs
# - Other crime
# - Other theft
# - Possession of weapons
# - Public order
# - Robbery
# - Shoplifting
# - Theft from the person
# - Vehicle crime
# - Violence and sexual offences
#
# Reported By:
# - Merseyside Police
#
# Last Outcome Categories:
# - ASB_FILL
# - Action to be taken by another organisation
# - Awaiting court outcome
# - Court result unavailable
# - Formal action is not in the public interest
# - Further action is not in the public interest
# - Further investigation is not in the public interest
# - Investigation complete; no suspect identified
# - Local resolution
# - Offender given a caution
# - Offender given a drugs possession warning
# - Status update unavailable
# - Suspect charged as part of another case
# - Unable to prosecute suspect
# - Under investigation

# %%
# Check distinct values in 'falls_within' to decide if it can be dropped
with engine.connect() as conn:
    result = conn.execute(text('SELECT DISTINCT falls_within FROM crime_data;'))
    distinct_falls_within = [row[0] for row in result.fetchall()]

print("Distinct values in 'falls_within':")
for val in distinct_falls_within:
    print(f"- {val}")
# Out:
# Distinct values in 'falls_within':
# - Merseyside Police

# %%
# Drop 'reported_by' and 'falls_within' columns as they contain the same repeated values (likely not informative)
with engine.connect() as conn:
    conn.execute(text('ALTER TABLE crime_data DROP COLUMN reported_by;'))
    conn.execute(text('ALTER TABLE crime_data DROP COLUMN falls_within;'))
    conn.commit()

# Fetch a sample to confirm columns dropped
with engine.connect() as conn:
    result = conn.execute(text('SELECT * FROM crime_data LIMIT 5;'))
    rows = result.fetchall()
    columns = result.keys()

df_head = pd.DataFrame(rows, columns=columns)
df_head.head()
# Out:
#                                             crime_id    month  longitude  \
# 0  7c903b55af24fe6dab7eb96fe696f8e7d57e05817f6730...  2024-06  -2.746819
# 1  461fe1ff825ef4cc740dafe58e9015449696d80978580a...  2024-06  -2.798814
# 2                                           ASB_FILL  2024-06  -2.871827
# 3  ebeec31356de0e9219711d81f3d8006d33c275e04e9e7a...  2024-06  -2.871229
# 4  b04da555d9c4f211ce48bf6453dc0f6257c63785727ec6...  2024-06  -2.871827
#
#     latitude                                        location  lsoa_code  \
# 0  53.389101  On or near Further/Higher Educational Building  E01012393
# 1  53.354705                      On or near Old Higher Road  E01012391
# 2  53.489763                    On or near Gilescroft Avenue  E01006448
# 3  53.489300                          On or near Watts Close  E01006448
# 4  53.489763                    On or near Gilescroft Avenue  E01006448
#
#        lsoa_name                 crime_type  \
# 0    Halton 001B                      Drugs
# 1    Halton 008B  Criminal damage and arson
# 2  Knowsley 001A      Anti-social behaviour
# 3  Knowsley 001A  Criminal damage and arson
# 4  Knowsley 001A  Criminal damage and arson
#
#                            last_outcome_category
# 0                               Local resolution
# 1  Investigation complete; no suspect identified
# 2                                       ASB_FILL
# 3  Investigation complete; no suspect identified
# 4                    Unable to prosecute suspect

# %%
from sqlalchemy import text
import pandas as pd

# Check for any rows where 'month' (YYYY-MM) is in the future compared to current year-month
with engine.connect() as conn:
    result = conn.execute(text("""
        SELECT month
        FROM crime_data
        WHERE substr(month, 1, 7) > strftime('%Y-%m', 'now')
        LIMIT 5;
    """))
    future_months = result.fetchall()
    columns = result.keys()

future_df = pd.DataFrame(future_months, columns=columns)
future_df
# Out:
# Empty DataFrame
# Columns: [month]
# Index: []

# %%
# Save the cleaned dataframe to the specified folder with the filename clean_data.csv
df.to_csv('/Users/jamesjackson/Documents/liverpool_crime_analysis/csv_files/clean_data.csv', index=False)
